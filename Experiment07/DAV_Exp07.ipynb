# %% [markdown]
# <a href="https://colab.research.google.com/github/ShivamGupta82/DAV_Lab/blob/master/Experiment07/DAV_Exp07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Experiment 7**
# ## **Aim : Perform the steps involved in Text Analytics in Python & R**
#
# **Lab Outcomes (LO):**
# Design Text Analytics Application on a given data set. (LO4)
#
# **Task to be performed :**
#
# 1. Explore Top-5 Text Analytics Libraries in Python (w.r.t Features & Applications)
#
# 2. Explore Top-5 Text Analytics Libraries in R (w.r.t Features & Applications)
#
# 3. Perform the following experiments using Python & R
# Tokenization (Sentence & Word)
# *   Frequency Distribution
# *   Remove stopwords & punctuations
# *   Lexicon Normalization (Stemming, Lemmatization)
# *   Part of Speech tagging
# *   Named Entity Recognization
# *   Scrape data from a website
#
# 4. Prepare a document with the Aim, Tasks performed, Program, Output, and Conclusion.

# %% [markdown]
# ## 1 . Using beautiful soup to scrap data

# %%
from bs4 import BeautifulSoup
import requests

url = 'https://en.wikipedia.org/wiki/Data_science#:~:text=Data%20science%20is%20an%20interdisciplinary,%2C%20structured%2C%20or%20unstructured%20data.'

# %%
scrap_data=''
# Send an HTTP GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the webpage
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find and extract specific elements or data from the webpage
    # Example: Extract all <p> tags
    paragraphs = soup.find_all('p')

    # Print the extracted data
    for paragraph in paragraphs:
        print(paragraph.text)
        scrap_data += paragraph.text
else:
    print('Failed to retrieve the webpage. Status code:', response.status_code)
# Out:
# Data science is an interdisciplinary academic field[1] that uses statistics, scientific computing, scientific methods, processes, algorithms and systems to extract or extrapolate knowledge and insights from potentially noisy, structured, or unstructured data.[2]
#
# Data science also integrates domain knowledge from the underlying application domain (e.g., natural sciences, information technology, and medicine).[3] Data science is multifaceted and can be described as a science, a research paradigm, a research method, a discipline, a workflow, and a profession.[4]
#
# ...

# %% [markdown]
# ## 2 . Using nltk to tokenize text

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
nltk.download('punkt')
text = scrap_data
sentences = sent_tokenize(text)
words = word_tokenize(text)
print("Sentences:", sentences)
print("Words:", words)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ...

# %% [markdown]
# ## **Frequency Distribution**

# %%
# Python
from nltk.probability import FreqDist

# Assuming 'words' is a list of words
fdist = FreqDist(words)

# Print frequency counts for each word
for word, frequency in fdist.items():
    print(f"{word}: {frequency}")
# Out:
# Data: 21
# science: 44
# is: 19
# an: 9
# interdisciplinary: 4
# academic: 1
# field: 10
# [: 51
# 1: 1
# ]: 51
# that: 18
# uses: 2
# statistics: 19
# ,: 119
# scientific: 2
# computing: 3
# methods: 6
# processes: 1
# algorithms: 4
# and: 79
# systems: 3
# to: 35
# extract: 3
# or: 6
# extrapolate: 1
# knowledge: 8
# insights: 8
# from: 16
# potentially: 1
# noisy: 1
# structured: 3
# unstructured: 2
# data: 78
# .: 63
# 2: 1
# also: 2
# integrates: 1
# domain: 5
# the: 48
# underlying: 1
# application: 4
# (: 4
# e.g.: 2
# natural: 1
# sciences: 1
# information: 8
# technology: 2
# medicine: 1
# ): 4
# 3: 1
# multifaceted: 1
# can: 2
# be: 4
# described: 3
# as: 18
# a: 33
# research: 2
# paradigm: 2
# method: 1
# discipline: 3
# workflow: 1
# profession: 1
# 4: 1
# ``: 14
# concept: 2
# unify: 1
# analysis: 18
# informatics: 1
# their: 3
# related: 3
# '': 14
# understand: 2
# analyze: 3
# actual: 1
# phenomena: 1
# with: 11
# 5: 1
# It: 1
# techniques: 3
# theories: 1
# ...

# %% [markdown]
# ## **Remove stopwords & punctuations**

# %%
# Python
from nltk.corpus import stopwords
import string
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
filtered_words = [word for word in words if word.lower() not in stop_words and word not in string.punctuation]
print("Filtered Words:", filtered_words)
# Out:
# Filtered Words: ['Data', 'science', 'interdisciplinary', 'academic', 'field', '1', 'uses', 'statistics', 'scientific', 'computing', 'scientific', 'methods', 'processes', 'algorithms', 'systems', 'extract', 'extrapolate', 'knowledge', 'insights', 'potentially', 'noisy', 'structured', 'unstructured', 'data', '2', 'Data', 'science', 'also', 'integrates', 'domain', 'knowledge', 'underlying', 'application', 'domain', 'e.g.', 'natural', 'sciences', 'information', 'technology', 'medicine', '3', 'Data', 'science', 'multifaceted', 'described', 'science', 'research', 'paradigm', 'research', 'method', 'discipline', 'workflow', 'profession', '4', 'Data', 'science', '``', 'concept', 'unify', 'statistics', 'data', 'analysis', 'informatics', 'related', 'methods', "''", '``', 'understand', 'analyze', 'actual', 'phenomena', "''", 'data', '5', 'uses', 'techniques', 'theories', 'drawn', 'many', 'fields', 'within', 'context', 'mathematics', 'statistics', 'computer', 'science', 'information', 'science', 
# ...

# %% [markdown]
# ## **Lexicon Normalization (Stemming, Lemmatization)**

# %%
import nltk
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.tokenize import word_tokenize
import string

# Download WordNet corpus
nltk.download('wordnet')

# Tokenize the text and remove punctuation
words = [word for word in word_tokenize(text) if word not in string.punctuation]

# Initialize stemmer and lemmatizer
porter = PorterStemmer()
lemmatizer = WordNetLemmatizer()

# Perform stemming and lemmatization
stemmed_words = [porter.stem(word) for word in words]
lemmatized_words = [lemmatizer.lemmatize(word.lower()) for word in words]

# Print the results
print("Stemmed Words:", stemmed_words)
print("Lemmatized Words:", lemmatized_words)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# ...

# %% [markdown]
# ## **Part of Speech tagging**

# %%
nltk.download('averaged_perceptron_tagger')
pos_tags = nltk.pos_tag(filtered_words)
print("Part of Speech Tags:", pos_tags)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# ...

# %% [markdown]
# ## **Named Entity Recognization**

# %%
# Python
import spacy

nlp = spacy.load("en_core_web_sm")
text2= scrap_data
doc = nlp(text2)
entities = [(entity.text, entity.label_) for entity in doc.ents]
print("Named Entities:", entities)
# Out:
# Named Entities: [('Jim Gray', 'PERSON'), ('fourth', 'ORDINAL'), ('Nathan Yau', 'PERSON'), ('Ben Fry', 'PERSON'), ('2015', 'DATE'), ('the American Statistical Association', 'ORG'), ('three', 'CARDINAL'), ('Nate Silver', 'ORG'), ('data.[17]', 'PRODUCT'), ('Vasant Dhar', 'PERSON'), ('Andrew Gelman', 'PERSON'), ('Columbia University', 'ORG'), ('Stanford', 'ORG'), ('David Donoho', 'PERSON'), ('1962', 'DATE'), ('John Tukey', 'PERSON'), ('1985', 'DATE'), ('the Chinese Academy of Sciences', 'ORG'), ('Beijing', 'GPE'), ('first', 'ORDINAL'), ('1992', 'DATE'), ('the University of Montpellier\xa0 II', 'ORG'), ('1974', 'DATE'), ('Peter Naur', 'PERSON'), ('1996', 'DATE'), ('the International Federation of Classification Societies', 'ORG'), ('first', 'ORDINAL'), ('1985', 'DATE'), ('the Chinese Academy of Sciences', 'ORG'), ('Beijing', 'GPE'), ('1997', 'DATE'), ('C.\xa0F. Jeff Wu', 'PERSON'), ('1998', 'DATE'), ('Hayashi Chikio', 'PERSON'), ('three', 'CARDINAL'), ('the 1990s', 'DATE'), ('2012', 'DATE
# ...

# %% [markdown]
# ## **Using R Library**

# %% [markdown]
# ## **Scrapping data**

# %%
# Install and load required libraries
install.packages("rvest")
library(rvest)

# Function to scrape text within <p> tags from a website
scrape_website <- function(url) {
  webpage <- read_html(url)
  paragraphs <- html_nodes(webpage, "p")  # Select only <p> tags
  text <- html_text(paragraphs)
  return(text)
}

# URL of the website to scrape
url <- "https://en.wikipedia.org/wiki/Data_science#:~:text=Data%20science%20is%20an%20interdisciplinary,%2C%20structured%2C%20or%20unstructured%20data."

# Scrape data from the website
paragraphs_text <- scrape_website(url)

# Print the scraped text within <p> tags
cat(paragraphs_text)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# ...

# %% [markdown]
# ## **Tokenizer**

# %%
install.packages('tokenizers')
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘Rcpp’, ‘SnowballC’

# %%
library(tokenizers)

# Assuming paragraphs_text is your input text
text <- paragraphs_text

# Tokenize words and sentences
word_tokens <- unlist(tokenize_words(text))
sentence_tokens <- unlist(tokenize_sentences(text))

# Print tokenized words
cat("\nTokenized words:\n")
print((word_tokens))

# Print tokenized sentences
cat("\nTokenized sentences:\n")
print(paste(sentence_tokens, collapse = " "))
# Out:
# Tokenized words:
#    [1] "data"              "science"           "is"
#    [4] "an"                "interdisciplinary" "academic"
#    [7] "field"             "1"                 "that"
#   [10] "uses"              "statistics"        "scientific"
#   [13] "computing"         "scientific"        "methods"
#   [16] "processes"         "algorithms"        "and"
#   [19] "systems"           "to"                "extract"
#   [22] "or"                "extrapolate"       "knowledge"
#   [25] "and"               "insights"          "from"
#   [28] "potentially"       "noisy"             "structured"
#   [31] "or"                "unstructured"      "data"
#   [34] "2"                 "data"              "science"
#   [37] "also"              "integrates"        "domain"
#   [40] "knowledge"         "from"              "the"
#   [43] "underlying"        "application"       "domain"
#   [46] "e.g"               "natural"           "sciences"
# ...

# %% [markdown]
# ## **Frequency Distribution**

# %%
word_freq <- table(word_tokens)

print("Most common words:")
print(head(sort(word_freq, decreasing = TRUE), 2))

print("Frequency of each word:")
print(word_freq)
# Out:
# [1] "Most common words:"
# word_tokens
# data  and
#  104   79
# [1] "Frequency of each word:"
# word_tokens
#                 1                10                11                12
#                 1                 1                 1                 1
#                13                14                15                16
#                 1                 1                 1                 1
#                17                18                19              1962
#                 1                 1                 1                 1
#              1974              1985             1990s              1992
#                 1                 2                 1                 1
#              1996              1997              1998                 2
#                 1                 1                 1                 1
#                20              2001              2002              2003
#                 2                 1                 1                 1
# ...

# %% [markdown]
# ## **Remove stopwords & punctuations**

# %%
install.packages('tm')
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘NLP’, ‘slam’, ‘BH’

# %%
library(tm)

filtered_tokens <- word_tokens[!word_tokens %in% stopwords("en")]

print("Filtered Tokens:")
print(filtered_tokens)
# Out:
# Loading required package: NLP
# [1] "Filtered Tokens:"
#    [1] "data"              "science"           "interdisciplinary"
#    [4] "academic"          "field"             "1"
#    [7] "uses"              "statistics"        "scientific"
#   [10] "computing"         "scientific"        "methods"
#   [13] "processes"         "algorithms"        "systems"
#   [16] "extract"           "extrapolate"       "knowledge"
#   [19] "insights"          "potentially"       "noisy"
#   [22] "structured"        "unstructured"      "data"
#   [25] "2"                 "data"              "science"
#   [28] "also"              "integrates"        "domain"
#   [31] "knowledge"         "underlying"        "application"
#   [34] "domain"            "e.g"               "natural"
#   [37] "sciences"          "information"       "technology"
#   [40] "medicine"          "3"                 "data"
#   [43] "science"           "multifaceted"      "can"
# ...

# %% [markdown]
# ## **Lexicon Normalization (Stemming, Lemmatization)**

# %%
stemming <- function(text) {
  corpus <- Corpus(VectorSource(text))
  corpus <- tm_map(corpus, stemDocument)
  return(corpus)
}

stemmed_corpus <- stemming(filtered_tokens)

print("Stemmed Tokens:")
print(unlist(sapply(stemmed_corpus, as.character)))
# Out:
# Warning message in tm_map.SimpleCorpus(corpus, stemDocument):
# “transformation drops documents”
# [1] "Stemmed Tokens:"
#    [1] "data"              "scienc"            "interdisciplinari"
#    [4] "academ"            "field"             "1"
#    [7] "use"               "statist"           "scientif"
#   [10] "comput"            "scientif"          "method"
#   [13] "process"           "algorithm"         "system"
#   [16] "extract"           "extrapol"          "knowledg"
#   [19] "insight"           "potenti"           "noisi"
#   [22] "structur"          "unstructur"        "data"
#   [25] "2"                 "data"              "scienc"
#   [28] "also"              "integr"            "domain"
#   [31] "knowledg"          "under"             "applic"
#   [34] "domain"            "e.g"               "natur"
#   [37] "scienc"            "inform"            "technolog"
#   [40] "medicin"           "3"                 "data"
#   [43] "scienc"            "multifacet"        "can"
# ...

# %%
install.packages('textstem')
library(textstem)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘zoo’, ‘dtt’, ‘ISOcodes’, ‘sylly.en’, ‘sylly’, ‘syuzhet’, ‘fastmatch’, ‘RcppParallel’, ‘stopwords’, ‘RcppArmadillo’, ‘english’, ‘mgsub’, ‘qdapRegex’, ‘koRpus.lang.en’, ‘hunspell’, ‘koRpus’, ‘lexicon’, ‘quanteda’, ‘textclean’, ‘textshape’
#
#
# Loading required package: koRpus.lang.en
#
# Loading required package: koRpus
#
# Loading required package: sylly
#
# For information on available language packages for 'koRpus', run
#
#   available.koRpus.lang()
#
# and see ?install.koRpus.lang()
#
#
#
# Attaching package: ‘koRpus’
#
#
# The following object is masked from ‘package:tm’:
#
#     readTagged

# %%
lemmatization <- function(text) {
  corpus <- Corpus(VectorSource(text))
  corpus <- tm_map(corpus, lemmatize_strings)
  return(corpus)
}

lemmatized_corpus <- lemmatization(text)

print("Lemmatized Tokens:")
print(unlist(sapply(lemmatized_corpus, as.character)))
# Out:
# Warning message in tm_map.SimpleCorpus(corpus, lemmatize_strings):
# “transformation drops documents”
# [1] "Lemmatized Tokens:"
#  [1] ""
#  [2] "datum science be a interdisciplinary academic field [ 1 ] that use statistic, scientific compute, scientific method, process, algorithm and system to extract or extrapolate knowledge and insight from potentially noisy, structure, or unstructured datum. [ 2 ]"
#  [3] "datum science also integrate domain knowledge from the underlie application domain ( e. g., natural science, information technology, and medicine ). [ 3 ] datum science be multifaceted and can be describe as a science, a research paradigm, a research method, a discipline, a workflow, and a profession. [ 4 ]"
# ...

# %% [markdown]
# ## **Part of Speech tagging and Named Entity Recognization**

# %%
library(udpipe)
x <- data.frame(doc_id = c("doc1", "doc2"),
                text = c("If an infusion reaction occurs, interrupt the infusion.",
                         "Houston we have a problem"))
x <- udpipe(x, "english")
x
# Out:
#    doc_id paragraph_id sentence_id
# 1  doc1   1            1
# 2  doc1   1            1
# 3  doc1   1            1
# 4  doc1   1            1
# 5  doc1   1            1
# 6  doc1   1            1
# 7  doc1   1            1
# 8  doc1   1            1
# 9  doc1   1            1
# 10 doc1   1            1
# 11 doc2   1            1
# 12 doc2   1            1
# 13 doc2   1            1
# 14 doc2   1            1
# 15 doc2   1            1
#    sentence                                                start end term_id
# 1  If an infusion reaction occurs, interrupt the infusion.  1     2   1
# 2  If an infusion reaction occurs, interrupt the infusion.  4     5   2
# 3  If an infusion reaction occurs, interrupt the infusion.  7    14   3
# 4  If an infusion reaction occurs, interrupt the infusion. 16    23   4
# 5  If an infusion reaction occurs, interrupt the infusion. 25    30   5
# 6  If an infusion reaction occurs, interrupt the infusion. 31    31   6
# ...

# %% [markdown]
# # **Conclusion**
#
#
# Upon completing our exploration of Python and R text analytics libraries, as well as understanding the steps involved in text analytics and recognizing the benefits it offers, we are now equipped with the knowledge and tools necessary to analyze and derive insights from textual data effectively in both Python and R environments. This comprehensive understanding allows us to apply text analytics techniques across various domains such as business intelligence, marketing analysis, customer service, healthcare, and more. By leveraging these techniques, we can extract valuable information from unstructured text data and make informed, data-driven decisions to drive success in our endeavors.
